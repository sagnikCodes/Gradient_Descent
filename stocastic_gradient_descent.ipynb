# %%
from sklearn import datasets
import numpy as np

# %%
diabetes=datasets.load_diabetes()
Input=np.array(diabetes["data"])
Output=np.array(diabetes["target"])
print(Input)
print(Output)
print(Input.shape,Output.shape)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990842
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06832974
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286377
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04687948
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452837
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00421986
#    0.00306441]]
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
# ...

# %%
def cost(x,y,m):
    M=len(x)
    answer=0
    for i in range(M):
        answer+=(y[i]-(m*x[i]).sum())**2
    return answer/M

# %%
Input=Input.tolist()
for i in range(len(Input)):
    Input[i].append(1)
Input=np.array(Input)
print(Input.shape)
# Out:
# (442, 11)

# %%
def gradient_descent_each_step(x,y,learning_rate,m):
    '''
    Input: x is 2D input array and y is 1D array and m is the coef_ array
    '''
    number_of_data_points=len(x)
    number_of_features=len(x[0])
    for j in range(number_of_features):
        value_of_m_j=0
        for i in range(number_of_data_points):
            value_of_m_j=(y[i]-(m*x[i]).sum())*(x[i][j])
            m[j]=m[j]-(learning_rate)*value_of_m_j
            #so each step yeh repeat karr stocastic gradient descent
    return m

# %%
def gradient_descent(x,y,learning_rate,number_of_iterations):
    m=np.zeros(len(x[0]))
    for i in range(number_of_iterations):
        old_cost=cost(x,y,m)
        m=gradient_descent_each_step(x,y,learning_rate,m)
        new_cost=cost(x,y,m)
        print(cost(x,y,m)," ",i)
    return m

# %%
m=gradient_descent(Input,Output,0.0000000001,1000)
for i in m:
    print(m,end=" ")
# Out:
# 29074.483948165183   0
# 29074.48599587803   1
# 29074.48804359109   2
# 29074.490091304287   3
# 29074.49213901775   4
# 29074.494186731332   5
# 29074.49623444513   6
# 29074.498282159057   7
# 29074.50032987321   8
# 29074.50237758751   9
# 29074.50442530197   10
# 29074.50647301668   11
# 29074.508520731564   12
# 29074.510568446585   13
# 29074.512616161846   14
# 29074.51466387718   15
# 29074.516711592823   16
# 29074.51875930859   17
# 29074.520807024513   18
# 29074.522854740644   19
# 29074.52490245695   20
# 29074.52695017345   21
# 29074.528997890102   22
# 29074.531045606935   23
# 29074.533093323967   24
# 29074.53514104119   25
# 29074.53718875856   26
# 29074.53923647613   27
# 29074.541284193914   28
# 29074.543331911842   29
# 29074.545379629988   30
# 29074.547427348283   31
# 29074.549475066735   32
# 29074.55152278538   33
# 29074.55357050423   34
# 29074.55561822325   35
# 29074.557665942448   36
# 29074.55971366181   37
# 29074.561761381396   38
# ...
